# %%
# define constants
input_dataset_parent_path = '/home/vamshikrishnadude/Downloads/Driving-range-Prediction-and-Energy-Consumption-in-EV-s/input_dataset/'
path_to_with_outliers_csv = input_dataset_parent_path+ 'eda_with_outliers.csv'
path_to_without_outliers_csv = input_dataset_parent_path+ 'eda_outliers_removed.csv'

# %%
# import libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sb

import os
from IPython.core.display import display

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# #### preprocessing with_outlier_data

# %%
df = pd.read_csv(path_to_with_outliers_csv);
display(df.head(5))
# Out:
#    trip_distance(km)  quantity(kWh)     tire_type  city  motor_way  \
# 0               50.0          12.29  Winter tires     0          0
# 1               43.0           8.68  Winter tires     0          1
# 2               44.0           1.50  Winter tires     0          1
# 3               76.0          14.44  Winter tires     0          1
# 4               15.0           6.84  Winter tires     1          0
#
#    country_roads driving_style  consumption(kWh/100km)  A/C  park_heating  \
# 0              1        Normal                    15.5    0             1
# 1              1        Normal                    18.0    0             1
# 2              1        Normal                    16.1    0             1
# 3              0        Normal                    19.0    0             1
# 4              0        Normal                    16.1    0             1
#
#    avg_speed(km/h)  ecr_deviation
# 0             47.0           -1.3
# 1             58.0            1.2
# ...

# %%
# Encode the categorical variables tire_type and driving style
# Encode the driving style first with Ordinal Encoding. as Normal, Moderate, Fast as some order and significance.

ordinalEncoder = OrdinalEncoder(categories=[['Normal', 'Moderate', 'Fast']])
df['encoded_driving_style'] = ordinalEncoder.fit_transform(df.driving_style.values.reshape(-1,1))

display(df.tail(5))
# Out:
#       trip_distance(km)  quantity(kWh)     tire_type  city  motor_way  \
# 3335               26.0           5.62  Winter tires     1          1
# 3336               77.0          14.25  Winter tires     1          1
# 3337               26.0           4.97  Winter tires     1          1
# 3338               20.0           4.76  Winter tires     1          1
# 3339               43.0           7.86  Winter tires     1          1
#
#       country_roads driving_style  consumption(kWh/100km)  A/C  park_heating  \
# 3335              1        Normal                    21.6    1             0
# 3336              1        Normal                    18.5    1             0
# 3337              1        Normal                    19.1    1             0
# 3338              1          Fast                    23.8    1             0
# 3339              1        Normal                    18.3    1             0
#
#       avg_speed(km/h)  ecr_deviation  encoded_driving_style
# ...

# %%
labelEncoder = LabelEncoder()
df['encoded_tire_type'] = labelEncoder.fit_transform(df.tire_type)

display(df.head(5))
# Out:
#    trip_distance(km)  quantity(kWh)     tire_type  city  motor_way  \
# 0               50.0          12.29  Winter tires     0          0
# 1               43.0           8.68  Winter tires     0          1
# 2               44.0           1.50  Winter tires     0          1
# 3               76.0          14.44  Winter tires     0          1
# 4               15.0           6.84  Winter tires     1          0
#
#    country_roads driving_style  consumption(kWh/100km)  A/C  park_heating  \
# 0              1        Normal                    15.5    0             1
# 1              1        Normal                    18.0    0             1
# 2              1        Normal                    16.1    0             1
# 3              0        Normal                    19.0    0             1
# 4              0        Normal                    16.1    0             1
#
#    avg_speed(km/h)  ecr_deviation  encoded_driving_style  encoded_tire_type
# ...

# %%
# drop two columns
df.drop(columns = ['tire_type', 'driving_style'], inplace=True)
df.head(5)
# Out:
#    trip_distance(km)  quantity(kWh)  city  motor_way  country_roads  \
# 0               50.0          12.29     0          0              1
# 1               43.0           8.68     0          1              1
# 2               44.0           1.50     0          1              1
# 3               76.0          14.44     0          1              0
# 4               15.0           6.84     1          0              0
#
#    consumption(kWh/100km)  A/C  park_heating  avg_speed(km/h)  ecr_deviation  \
# 0                    15.5    0             1             47.0           -1.3
# 1                    18.0    0             1             58.0            1.2
# 2                    16.1    0             1             43.0           -0.7
# 3                    19.0    0             1             76.0            2.2
# 4                    16.1    0             1             23.0           -0.7
#
#    encoded_driving_style  encoded_tire_type
# 0                    0.0                  1
# ...

# %%
# save file
df.to_csv(input_dataset_parent_path+'final_preprocessed_with_outliers.csv', index=False)

# %% [markdown]
# ### preprocessing without_outliers_data

# %%
df_without = pd.read_csv(path_to_without_outliers_csv);

# %%
ordinalEncoder = OrdinalEncoder(categories=[['Normal', 'Moderate', 'Fast']])
df_without['encoded_driving_style'] = ordinalEncoder.fit_transform(df_without.driving_style.values.reshape(-1,1))

labelEncoder = LabelEncoder()
df_without['encoded_tire_type'] = labelEncoder.fit_transform(df_without.tire_type)

# %%
df_without.drop(columns = ['tire_type', 'driving_style'], inplace=True)
df_without.head(5)
# Out:
#    trip_distance(km)  quantity(kWh)  city  motor_way  country_roads  \
# 0               50.0          12.29     0          0              1
# 1               43.0           8.68     0          1              1
# 2               44.0           1.50     0          1              1
# 3               76.0          14.44     0          1              0
# 4               15.0           6.84     1          0              0
#
#    consumption(kWh/100km)  A/C  park_heating  avg_speed(km/h)  ecr_deviation  \
# 0                    15.5    0             1             47.0           -1.3
# 1                    18.0    0             1             58.0            1.2
# 2                    16.1    0             1             43.0           -0.7
# 3                    19.0    0             1             76.0            2.2
# 4                    16.1    0             1             23.0           -0.7
#
#    encoded_driving_style  encoded_tire_type
# 0                    0.0                  1
# ...

# %%
# save file
df_without.to_csv(input_dataset_parent_path+'final_preprocessed_without_outliers.csv', index=False)
